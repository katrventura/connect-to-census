# %%
# !pip install censusgeocode
# Out:
# Requirement already satisfied: censusgeocode in /Users/katrinaventura/.pyenv/versions/3.11.6/lib/python3.11/site-packages (0.5.2)
# Requirement already satisfied: requests[security]<3,>=2.27.0 in /Users/katrinaventura/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from censusgeocode) (2.31.0)
# Requirement already satisfied: requests-toolbelt<1,>=0.9.0 in /Users/katrinaventura/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from censusgeocode) (0.10.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/katrinaventura/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from requests[security]<3,>=2.27.0->censusgeocode) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /Users/katrinaventura/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from requests[security]<3,>=2.27.0->censusgeocode) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/katrinaventura/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from requests[security]<3,>=2.27.0->censusgeocode) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/katrinaventura/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from requests[security]<3,>=2.27.0->censusgeocode) (2023.7.22)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
import glob
import json
import requests
import pandas as pd
from pprint import pprint

# %% [markdown]
# # Census Examples

# %% [markdown]
# This notebook uses the `censusgeocode` package in Python (which is simply a wrapper around the US Census' official Geocoder API) to get census geographies for list of addresses or lat/longs
#
# - https://pypi.org/project/censusgeocode/

# %% [markdown]
# ### Step 1 | Grab your data at the address level

# %%
df = pd.read_csv('baltimore-lmop.csv')

# %%
# remove null in lat, long

df = df.dropna(subset=['lat', 'long'])

# %% [markdown]
# ### Step 2 | Geoode Lat/Long if they're not already present
#
# It already exists in this dataset. Census geocode has a function to go from addresss --> lat/long, but I haven't had time to implement it here. This dataset already has lat/longs. Message me if you're struggling with this step.

# %% [markdown]
# ### Step 3 | Get Census Geographies

# %%
# Code adapted from:
# https://gis.stackexchange.com/questions/363830/applying-the-censusgeocode-package-to-an-entire-dataframe-of-geocoded-data
# Defines a geocode function that accepts lat/long and spits out geographies
# The code then runs that funciton in parllel (for speed).

import pandas as pd
import censusgeocode as cg
from concurrent.futures import ThreadPoolExecutor
from tqdm.notebook import tqdm
import glob
import json
import requests
import pandas as pd
from pprint import pprint
from tqdm import tqdm


import requests_cache
cache = requests_cache.CachedSession("geocode_cache", backend="filesystem")

def geocode(lat, lng):
    try:
        url = "https://geocoding.geo.census.gov/geocoder/geographies/coordinates"
        params = {
            "x": lng,
            "y": lat,
            "benchmark": "Public_AR_Census2020",
            "vintage": "Census2020_Census2020",
            "format": "json"
        }
        response = cache.get(url, params=params)
        response.raise_for_status()
        data = response.json()
        census = data['result']['geographies']['Census Blocks'][0]
        return census
    except Exception as e:
        print(f"Error geocoding ({lat}, {lng}): {e}")
        return None

def bulk_geocode(latitudes, longitudes):
    """
    Geocode a list of latitudes and longitudes in parallel (for speed).
    """

    with ThreadPoolExecutor() as tpe:
        latitudes = df['lat']
        longitudes = df['long']
        mapped_results = tpe.map(geocode, latitudes, longitudes)
        data = list(tqdm(mapped_results, total=len(df)))

    return pd.DataFrame(data)

census_geos_df = bulk_geocode(df['lat'], df['long']) 
census_geos_df.head()
# Out:
# 100%|██████████| 48/48 [00:00<00:00, 172.95it/s]
#   SUFFIX  POP100            GEOID      CENTLAT BLOCK  AREAWATER STATE  \
# 0            303  240276030013008  +39.3107759  3008      20102    24
# 1             40  240037516002006  +38.9992836  2006      43753    24
# 2            121  240098610033000  +38.3826801  3000          0    24
# 3            138  240199702002028  +38.6669238  2028     130246    24
# 4              0  245102604022006  +39.3120516  2006          0    24
#
#   BASENAME              OID LSADC  ...   TRACT       CENTLON BLKGRP  AREALAND  \
# 0     3008  210701008433656    BK  ...  603001  -076.9165175      3   3082515
# 1     2006  210701008460394    BK  ...  751600  -076.5779410      2   2964312
# 2     3000  210701008422291    BK  ...  861003  -076.4343048      3    612423
# 3     2028  210701007975810    BK  ...  970200  -075.8859696      2   4509149
# 4     2006  210701007704285    BK  ...  260402  -076.5458312      2    409395
#
#   HU100      INTPTLON  MTFCC  LWBLKTYP  UR COUNTY
# 0    85  -076.9181838  G5040         B   R    027
# 1    10  -076.5780772  G5040         B   R    003
# 2    88  -076.4343048  G5040         L   U    009
# 3    61  -075.8860477  G5040         B   R    019
# 4     0  -076.5458312  G5040         L   U    510
#
# [5 rows x 24 columns]

# %%
to_keep = ['GEOID', 'STATE', 'COUNTY', 'TRACT', 'BLOCK']
census_geos_df = census_geos_df[to_keep]
census_geos_df
# Out:
#               GEOID STATE COUNTY   TRACT BLOCK
# 0   240276030013008    24    027  603001  3008
# 1   240037516002006    24    003  751600  2006
# 2   240098610033000    24    009  861003  3000
# 3   240199702002028    24    019  970200  2028
# 4   245102604022006    24    510  260402  2006
# 5   240338006071007    24    033  800607  1007
# 6   240338006071007    24    033  800607  1007
# 7   240338006071007    24    033  800607  1007
# 8   240150309033011    24    015  030903  3011
# 9   240479512001053    24    047  951200  1053
# 10  240178509041038    24    017  850904  1038
# 11  240054113022003    24    005  411302  2003
# 12  240054113022003    24    005  411302  2003
# 13  240217512011014    24    021  751201  1014
# 14  240037401062024    24    003  740106  2024
# 15  240430117003016    24    043  011700  3016
# 16  240230006011003    24    023  000601  1003
# 17  240037511022010    24    003  751102  2010
# 18  240317012111000    24    031  701211  1000
# 19  240317012111000    24    031  701211  1000
# 20  240253052003000    24    025  305200  3000
# 21  240054113021018    24    005  411302  1018
# 22  240135142013014    24    013  514201  3014
# 23  240419605021018    24    041  960502  1018
# 24  240419605021018    24    041  960502  1018
# 25  240119552011042    24    011  955201  1042
# 26  240037410001002    24    003  741000  1002
# 27  240010019002000    24    001  001900  2000
# 28  240276027002006    24    027  602700  2006
# 29  240450103001029    24    045  010300  1029
# 30  240450103001027    24    045  010300  1027
# 31  240054524001002    24    005  452400  1002
# 32  240135041003004    24    013  504100  3004
# 33  240317001032010    24    031  700103  2010
# 34  240317001032010    24    031  700103  2010
# 35  240199702002028    24    019  970200  2028
# 36  245102505002010    24    510  250500  2010
# 37  240178503002004    24    017  850300  2004
# 38  245102505001019    24    510  250500  1019
# 39  240217519042017    24    021  751904  2017
# 40  240430117003004    24    043  011700  3004
# 41  240230006011000    24    023  000601  1000
# 42  240378760041005    24    037  876004  1005
# 43  240338004111008    24    033  800411  1008
# 44  240338004111008    24    033  800411  1008
# 45  240037301023040    24    003  730102  3040
# 46  240037080044000    24    003  708004  4000
# 47  240399308002029    24    039  930800  2029

# %%
df_with_geos = pd.concat(
    [ 
        df.reset_index(drop=True),
        census_geos_df.reset_index(drop=True)
    ], 
    axis=1)

df_with_geos.head()
# Out:
#     GHGRP ID  Landfill ID              Landfill Name State  \
# 0  1007291.0          734            Alpha Ridge SLF    MD
# 1        NaN          735              Annapolis SLF    MD
# 2        NaN          736                 Appeal SLF    MD
# 3  1000331.0        10120  Beulah Municipal Landfill    MD
# 4        NaN          740           Bowley's Lane LF    MD
#
#                     Physical Address            City          County  \
# 0           2350 Marriottsville Road  Marriottsville          Howard
# 1                    Defense Highway       Annapolis    Anne Arundel
# 2                                NaN           Lusby         Calvert
# 3  6815 East New Market Ellwood Road         Hurlock      Dorchester
# 4                      Bowley's Lane       Baltimore  Baltimore city
#
#    Zip Code        lat       long  ... Actual MW Generation Rated MW Capacity  \
# 0   21104.0  39.305776 -76.898803  ...                 0.58             1.059
# 1   21401.0  38.992000 -76.573000  ...                  NaN               NaN
# 2   20657.0  38.381112 -76.438334  ...                  NaN               NaN
# 3   21643.0  38.673500 -75.899400  ...                  NaN               NaN
# 4   21206.0  39.313800 -76.544400  ...                  NaN               NaN
#
#    LFG Flow to Project (mmscfd)  \
# 0                          0.28
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#    Current Year Emission Reductions (MMTCO2e/yr) - Direct  \
# 0                                             0.0294
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Current Year Emission Reductions (MMTCO2e/yr) - Avoided            GEOID  \
# 0                                             0.0028       240276030013008
# 1                                                NaN       240037516002006
# 2                                                NaN       240098610033000
# 3                                                NaN       240199702002028
# 4                                                NaN       245102604022006
#
#    STATE COUNTY   TRACT  BLOCK
# 0     24    027  603001   3008
# 1     24    003  751600   2006
# 2     24    009  861003   3000
# 3     24    019  970200   2028
# 4     24    510  260402   2006
#
# [5 rows x 38 columns]

# %%
# save to csv

df_with_geos.to_csv('baltimore-lmop-with-geocodes.csv', index=False)

# %% [markdown]
# # Step 4 | Pick a geographical level and get Census data
# Do you want Census data at the state level? county? tract? block?
#
# 1. Pick a geographical level.
# 2. See `census-example.ipynb` if you want to learn how to get Census data at your desired level

# %%
# state level: tract

df_with_geos['GEOID'] = df_with_geos['GEOID'].astype(str)

# %% [markdown]
# # Hope that helps!
